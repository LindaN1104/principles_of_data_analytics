# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Source the Data Set

# %% [markdown]
# Note to self, add info about data set and source link.
# Also...Import the Iris data set from the sklearn.datasets module.
# Explain, in your own words, what the load_iris() function returns.

# %%
# Dataframes
import pandas as pd

# Machine learning library that contains example datasets
import sklearn as skl

# %% [markdown]
# CSV link for the iris dataset = https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv

# %% [markdown]
# ## Task 2: Explore the Data Structure

# %% [markdown]
# The table below shows the shape of the dataset. The feature names are in the first row i.e. sepal lenght. Column 1 contains the number of the specimen. Column 2 shows sepal lenght. Column 3 outlines sepal with. Column 4 contains petal length. Column 5 shows petal width. And lastly Column 6 highlights the species.
#
# Note to self... include if width is in MM, CM, etc.

# %%
# Load the dataset from the CSV
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Task 3: Summarise the Data

# %% [markdown]
# The table below contains the mean, minimum, maximum, standard deviation, and median for each feature in the dataset.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Task 4: Visualise Features (Plot histograms for each feature using matplotlib. Add appropriate titles and axis labels.)

# %% [markdown]
# The four features of the Iris Dataset will be displayed in the form of histograms below.
#
# The features are sepal length, sepal width, petal length, petal width.
#
# To create the histogram [matplotlib.pyplot](https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/) needs to be imported.

# %%
# This module is a tool for creating visualisations

import matplotlib.pyplot as plt

# %% [markdown]
# [Numpy](https://www.w3schools.com/python/numpy/numpy_intro.asp#:~:text=NumPy%20is%20a%20Python%20library,you%20can%20use%20it%20freely.) also needs to be imported.

# %%
# A tool that speeds up and simplifies maths and data manipulation tasks
import numpy as np

# %% [markdown]
# Histogram for Sepal Length

# %%
target_names = df['species'].unique() # Define the target names based on species

colors = ['pink', 'purple', 'magenta'] # Create a color list for each species

fig, ax = plt.subplots() # Create the figure and axis for the plot

for label, color in zip(target_names, colors): # Plot the histograms by species
    species_data = df[df['species'] == label]
    ax.hist(species_data['sepal_length'], label=label, color=color, edgecolor="black", stacked=True) # Give each column a black border and make them stacked

ax.set_xlabel('Sepal Length in cm') # Set X axis label
ax.set_ylabel("Frequency in singular units") # Set the Y axis label
ax.set_title("Sepal Length Distribution by Species", fontstyle='italic') # Set the title, in italics

ax.legend(loc='upper right', title="Flower Species") # Add a legend, and legend title

plt.show() # Show the plot

# %% [markdown]
# Histogram for Sepal Width

# %%
target_names = df['species'].unique() # Define the target names based on species

colors = ['pink', 'purple', 'magenta'] # Create a color list for each species

fig, ax = plt.subplots() # Create the figure and axis for the plot

for label, color in zip(target_names, colors): # Plot the histograms by species
    species_data = df[df['species'] == label]
    ax.hist(species_data['sepal_width'], label=label, color=color, edgecolor="black", stacked=True) # Give each column a black border and make them stacked

ax.set_xlabel('Sepal Width in cm') # Set X axis label
ax.set_ylabel("Frequency in singular units") # Set the Y axis label
ax.set_title("Sepal Width Distribution by Species", fontstyle='italic') # Set the title, in italics

ax.legend(loc='upper right', title="Flower Species") # Add a legend, and legend title

plt.show() # Show the plot

# %% [markdown]
# Histogram for Petal Length

# %%
target_names = df['species'].unique() # Define the target names based on species

colors = ['pink', 'purple', 'magenta'] # Create a color list for each species

fig, ax = plt.subplots() # Create the figure and axis for the plot

for label, color in zip(target_names, colors): # Plot the histograms by species
    species_data = df[df['species'] == label]
    ax.hist(species_data['petal_length'], label=label, color=color, edgecolor="black", stacked=True) # Give each column a black border and make them stacked

ax.set_xlabel('Petal Length in cm') # Set X axis label
ax.set_ylabel("Frequency in singular units") # Set the Y axis label
ax.set_title("Petal Length Distribution by Species", fontstyle='italic') # Set the title, in italics

ax.legend(loc='upper right', title="Flower Species") # Add a legend, and legend title

plt.show() # Show the plot

# %% [markdown]
# Histogram for Petal Width

# %%
target_names = df['species'].unique() # Define the target names based on species

colors = ['pink', 'purple', 'magenta'] # Create a color list for each species

fig, ax = plt.subplots() # Create the figure and axis for the plot

for label, color in zip(target_names, colors): # Plot the histograms by species
    species_data = df[df['species'] == label]
    ax.hist(species_data['petal_width'], label=label, color=color, edgecolor="black", stacked=True) # Give each column a black border and make them stacked

ax.set_xlabel('Petal Width in cm') # Set X axis label
ax.set_ylabel("Frequency in singular units") # Set the Y axis label
ax.set_title("Petal Width Distribution by Species", fontstyle='italic') # Set the title, in italics

ax.legend(loc='upper right', title="Flower Species") # Add a legend, and legend title

plt.show() # Show the plot

# %% [markdown]
# Histogram for All Four Features

# %% [markdown]
# Source code from https://stackoverflow.com/questions/45721083/unable-to-plot-4-histograms-of-iris-dataset-features-using-matplotlib

# %% [markdown]
# https://chatgpt.com/c/67d738db-6ee8-8005-af04-77088f6f63b0

# %%
iris = datasets.load_iris() # Load the Iris dataset

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 8)) # Create subplots
colors = ['pink', 'purple', 'magenta']

for i, ax in enumerate(axes.flat): # Loop over each feature to create stacked histograms
    # Extract data for each class
    data = [iris.data[iris.target == label, i] for label in range(len(iris.target_names))]
    
    # Create a stacked histogram with black outlines
    ax.hist(data, label=iris.target_names, color=colors, stacked=True, edgecolor='black')
    
    # Set the title in italics
    ax.set_title(f'{iris.feature_names[i]} distribution by species', style='italic')
    
    # Set labels and legend
    ax.set_xlabel(iris.feature_names[i])
    ax.set_ylabel("Frequency in singular units")
    ax.legend(loc='upper right')

# Show the plot
plt.tight_layout()
plt.show()

# https://chatgpt.com/c/67d741f4-86a4-8005-b08c-df18de12faac

# %% [markdown]
# ## Task 5: Investigate Relationships

# %% [markdown]
# Choose any two features from the data set and create a scatter plot of them.
# Color-code the three different classes of the scatter plot points.

# %% [markdown]
# ## Task 6: Analyse Relationship

# %% [markdown]
# Use numpy.polyfit to add a regression line to the scatter plot from Task 5.

# %% [markdown]
# ## Task 7: Analyse Class Distributions

# %% [markdown]
# Create box-plots of the petal lengths for each of the three classes.

# %% [markdown]
# ## Task 8: Compute Correlations

# %% [markdown]
# Calculate the correlation coefficients between the features.
# Display the results as a heatmap using matplotlib.

# %% [markdown]
# ## Task 9: Fit a Sample Linear Regression

# %% [markdown]
# For your two features in Task 5, calculate the coefficient of determination
# R
# 2
# .
# Re-create the plot from Task 6 and annotate it with the
# R
# 2
#  value

# %% [markdown]
# ## Task 10: Too Many Features

# %% [markdown]
# Use seaborn to create a pairplot of the data set.
# Explain, in your own words, what the pairplot depicts.

# %% [markdown]
# ## End
