# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Source the Data Set

# %% [markdown]
# Note to self, add info about data set and source link.
# Also...Import the Iris data set from the sklearn.datasets module.
# Explain, in your own words, what the load_iris() function returns.

# %%
# Dataframes
import pandas as pd

# Machine learning library that contains example datasets
import sklearn as skl

# %% [markdown]
# CSV link for the iris dataset = https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv

# %% [markdown]
# ## Task 2: Explore the Data Structure

# %% [markdown]
# The table below shows the shape of the dataset. The feature names are in the first row i.e. sepal lenght. Column 1 contains the number of the specimen. Column 2 shows sepal lenght. Column 3 outlines sepal with. Column 4 contains petal length. Column 5 shows petal width. And lastly Column 6 highlights the species.
#
# Note to self... include if width is in MM, CM, etc.

# %%
df = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Task 3: Summarise the Data

# %% [markdown]
# The table below contains the mean, minimum, maximum, standard deviation, and median for each feature in the dataset.

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Task 4: Visualise Features

# %% [markdown]
# Plot histograms for each feature using matplotlib.
# Add appropriate titles and axis labels.

# %% [markdown]
# The features are sepal length, sepal width, petal length, petal width. Below, you will see a seperate histogram for each of those features.

# %% [markdown]
# To create the histogram matplotlib.pyplot needs to be imported. I then shortened to plt for convenience, as it less characters to type. ... maybe include what is matplotlib?
# https://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# come back to.. may not actually be needed because all of sklearn was imported earlier
from sklearn import datasets

# %%
# Load Iris Dataset
iris = datasets.load_iris()

# %% [markdown]
# Histogram for Sepal Length

# %%
# Single histogram for sepal length (first feature)
fig, ax = plt.subplots()
colors = ['pink', 'purple', 'magenta']

for label, color in zip(range(len(iris.target_names)), colors):
    ax.hist(iris.data[iris.target == label, 0], label=iris.target_names[label], 
            color=color, edgecolor="black")  # Add black outline
    
ax.set_xlabel(iris.feature_names[0])  # Sepal length
ax.set_ylabel("Frequency in singular units")
ax.set_title("Sepal Length Distribution by Species")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# Histogram for Sepal Width

# %%
# Single histogram for sepal width (second feature)
fig, ax = plt.subplots()
colors = ['pink', 'purple', 'magenta']

for label, color in zip(range(len(iris.target_names)), colors):
    ax.hist(iris.data[iris.target == label, 0], label=iris.target_names[label], 
            color=color, edgecolor="black")  # Add black outline

ax.set_xlabel(iris.feature_names[1])  # Sepal width
ax.set_ylabel("Frequency in singular units")
ax.set_title("Sepal Width Distribution by Species")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# Histogram for Petal Length

# %%
# Single histogram for petal length (third feature)
fig, ax = plt.subplots()
colors = ['pink', 'purple', 'magenta']

for label, color in zip(range(len(iris.target_names)), colors):
    ax.hist(iris.data[iris.target == label, 0], label=iris.target_names[label], 
            color=color, edgecolor="black")  # Add black outline
    
ax.set_xlabel(iris.feature_names[2])  # Petal length
ax.set_ylabel("Frequency in singular units") # Y axis name
ax.set_title("Petal Length Distribution by Species") # X axis name
ax.legend(loc='upper right') # where the legend is located
plt.show()

# %% [markdown]
# Histogram for Petal Width

# %%
# Single histogram for petal width (fourth feature)
fig, ax = plt.subplots()
colors = ['pink', 'purple', 'magenta']

for label, color in zip(range(len(iris.target_names)), colors):
    ax.hist(iris.data[iris.target == label, 0], label=iris.target_names[label], 
            color=color, edgecolor="black")  # Add black outline
    
ax.set_xlabel(iris.feature_names[3])  # Petal width
ax.set_ylabel("Frequency in singular units")
ax.set_title("Petal Width Distribution by Species")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# Histogram for All Four Features

# %%
# Create a figure
fig, ax = plt.subplots()
colors = ['pink', 'purple', 'magenta']

# Extract sepal length data for each species
data = [iris.data[iris.target == label, 0] for label in range(len(iris.target_names))]

# Create a stacked histogram
ax.hist(data, bins=15, stacked=True, color=colors, edgecolor="black", label=iris.target_names)

# Labels and title
ax.set_xlabel(iris.feature_names[0])  # Sepal length
ax.set_ylabel("Frequency")
ax.set_title("Stacked Sepal Length Distribution by Species")
ax.legend(loc='upper right')

# Show the plot
plt.show()

# %% [markdown]
# Source code from https://stackoverflow.com/questions/45721083/unable-to-plot-4-histograms-of-iris-dataset-features-using-matplotlib

# %%
fig, axes = plt.subplots(nrows= 2, ncols=2)
colors= ['pink', 'purple', 'magenta']

for i, ax in enumerate(axes.flat):
    for label, color in zip(range(len(iris.target_names)), colors):
        ax.hist(iris.data[iris.target==label, i], label=             
                            iris.target_names[label], color=color)
        ax.set_xlabel(iris.feature_names[i])  
        ax.legend(loc='upper right')

# %% [markdown]
# https://chatgpt.com/c/67d738db-6ee8-8005-af04-77088f6f63b0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
import pandas as pd

# Load the dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Plot histogram for all features in one plot
plt.figure(figsize=(10, 6))
for column in df.columns:
    plt.hist(df[column], bins=20, alpha=0.5, label=column, edgecolor="black")

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Iris Dataset Features")
plt.legend()
plt.show()

# %% [markdown]
# ## Task 5: Investigate Relationships

# %% [markdown]
# Choose any two features from the data set and create a scatter plot of them.
# Color-code the three different classes of the scatter plot points.

# %% [markdown]
# ## Task 6: Analyse Relationship

# %% [markdown]
# Use numpy.polyfit to add a regression line to the scatter plot from Task 5.

# %% [markdown]
# ## Task 7: Analyse Class Distributions

# %% [markdown]
# Create box-plots of the petal lengths for each of the three classes.

# %% [markdown]
# ## Task 8: Compute Correlations

# %% [markdown]
# Calculate the correlation coefficients between the features.
# Display the results as a heatmap using matplotlib.

# %% [markdown]
# ## Task 9: Fit a Sample Linear Regression

# %% [markdown]
# For your two features in Task 5, calculate the coefficient of determination
# R
# 2
# .
# Re-create the plot from Task 6 and annotate it with the
# R
# 2
#  value

# %% [markdown]
# ## Task 10: Too Many Features

# %% [markdown]
# Use seaborn to create a pairplot of the data set.
# Explain, in your own words, what the pairplot depicts.

# %% [markdown]
# ## End
